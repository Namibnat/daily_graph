# %% [markdown]
#   # Project: Graph of just random

# %%
# Standard imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# ## Get Data

# %%
# Made Up City Temparatures
raw_data = {'city 1': {'Jan': 26,
  'Feb': -7,
  'Mar': 28,
  'Apr': -3,
  'May': 17,
  'Jun': 6,
  'Jul': 9,
  'Aug': 11,
  'Sep': -8,
  'Oct': -1,
  'Nov': 21},
 'city 2': {'Jan': 10,
  'Feb': 17,
  'Mar': -4,
  'Apr': -5,
  'May': 35,
  'Jun': 21,
  'Jul': -9,
  'Aug': 1,
  'Sep': 8,
  'Oct': 31,
  'Nov': 21}}

# %% [markdown]
# ## Clean and organize dataframe

# %%
data = pd.DataFrame(raw_data)
data.index
# Out:
# Index(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
#        'Nov'],
#       dtype='object')

# %% [markdown]
# ## Graph the data

# %%
# plt.plot(data)
# plt.show()

# Create the figure and axes objects
fig, ax = plt.subplots()

# Plot the data for both cities
ax.plot(data.index, data['city 1'], label='City 1')
ax.plot(data.index, data['city 2'], label='City 2')

# Set the x and y labels
ax.set_xlabel('Month')
ax.set_ylabel('Temperature (C)')

# Add a legend to the plot
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# This data does not provide any conclusion.  This is simply graph #1 to get started

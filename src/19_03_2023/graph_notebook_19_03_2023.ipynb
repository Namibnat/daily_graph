# %% [markdown]
# # Project: Graph of ...

# %%
# Standard imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# ## Get Data

# %% [markdown]
# Data source: https://www.kaggle.com/datasets/muthuj7/weather-dataset

# %%
path = os.path.join('/', *os.getcwd().split('/')[1:-2], '.data')

data = pd.read_csv(os.path.join(path, 'weather.csv'))
data.shape
# Out:
# (366, 22)

# %% [markdown]
# ## Clean and organize dataframe

# %%
data = pd.DataFrame(raw_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = pd.DataFrame(raw_data)
#
# NameError: name 'raw_data' is not defined

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
temp_measurements = data[['MinTemp', 'MaxTemp']]
temp_measurements.head()
# Out:
#    MinTemp  MaxTemp
# 0      8.0     24.3
# 1     14.0     26.9
# 2     13.7     23.4
# 3     13.3     15.5
# 4      7.6     16.1

# %%
temp_measurements.shape
# Out:
# (366, 2)

# %% [markdown]
# ## Graph the data

# %%
# plot the scatter plot
fig, ax = plt.subplots()
colors = {'MinTemp':'blue', 'MaxTemp':'red'}

# fit a polynomial regression line to the data
coefficients = np.polyfit(temp_measurements['MinTemp'], temp_measurements['MaxTemp'], 1)
p = np.poly1d(coefficients)
ax.plot(temp_measurements['MinTemp'], p(temp_measurements['MinTemp']), color='C4')

ax.scatter(temp_measurements['MinTemp'], temp_measurements['MaxTemp'], color='C1')
ax.set_xlabel('Minimum Temperatures')
ax.set_ylabel('Maximum Temperatures')

# set the range of the x and y axes
plt.xlim(-10, 30)
plt.ylim(5, 40)

ax.set_title('The relationship between minimum and maximum temparatures')

plt.savefig("max_to_min_temp.png")


plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The data suggests...there is a relationship between minimum and maximum temperatures.

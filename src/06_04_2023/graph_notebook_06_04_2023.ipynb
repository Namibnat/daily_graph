# %% [markdown]
# # Project: Graph of ...

# %%
# Standard imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
import ssl
import requests

# %matplotlib inline

# %% [markdown]
# ## Make a graph

# %%
data = {
    'A': [7, 5, 1, 9, 8, 12, 3, 4, 10, 7],
    'B': [16, 2, 19, 10, 8, 28, 25, 31, 3, 4],
    'C': [17, 5, 23, 9, 2, 32, 9, 26, 14, 11],
    'D': [21, 27, 15, 12, 6, 33, 24, 30, 10, 18],
}


fig, ax = plt.subplots()

for column in df.columns:
    ax.bar(column, df[column].mean(), edgecolor='#383838')

plt.title('A graph on a busy day when I don\'t have time to graph')
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The data suggests...

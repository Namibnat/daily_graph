# %% [markdown]
# # Project: Graph of random color rings

# %%
# Standard imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
import ssl
import requests

# %matplotlib inline

import random

# %% [markdown]
# ## Graph the data

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# Create a new figure and axis
fig, ax = plt.subplots()

colors = ["#FF69B4","#7DF9FF","#FFFF00","#9B59B6","#FF7F50"]
places = [(random.randint(3, 17), random.randint(3, 17)) for _ in range(5)]

for place, color in zip(places, colors):

    # Create a circle patch with center (0, 0) and radius 1
    circle = Circle(place, radius=2.15, clip_on=False, zorder=10, linewidth=2.5,
                   edgecolor=color, facecolor='none',
                   path_effects=[withStroke(linewidth=7, foreground='white')])

    # Add the circle patch to the axis
    ax.add_patch(circle)

# Set the axis limits and title
ax.set_xlim(0, 20)
ax.set_ylim(0, 20)

ax.set_title('Example Circle Plot')

# Display the plot
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The data suggests...you can do fun color stuff with matplotlib :)
